# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
q1 = """SELECT *
FROM [damir.Table_avec_libelle] 
LIMIT 60000
"""

data_damir = pd.read_gbq(q1, "data-kit")
# Out:
# Job not yet complete...

# %%
data_damir['denombrement'].count()
# Out:
# 60000

# %%
data_damir.head(5)
# Out:
#   coefficient_global denombrement nature_d_assurance qualite_du_beneficiaire  \
# 0              16,00           14                  1                       1
# 1               1,00            1                  1                       1
# 2              46,00           39                  1                       1
# 3               6,00            4                  1                       1
# 4              94,00           74                  1                       1
#
#   complement_d_acte depassement_d_honoraires  \
# 0                 0                     0,00
# 1                 0                     0,00
# 2                 0                     0,00
# 3                 0                     0,00
# 4                 0                     0,00
#
#   cpam_d_affiliation_du_beneficiaire  \
# 0                          764-Rouen
# 1                          764-Rouen
# 2                          771-Melun
# 3                          771-Melun
# ...
